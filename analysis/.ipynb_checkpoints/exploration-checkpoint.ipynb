# %% [markdown]
# # Exploracion de base datos!!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Cargando la base de datos
# https://www.kaggle.com/miroslavsabo/young-people-survey
base = pd.read_csv('responses.csv')
#Eliminando casos con NAs
base1 = base.dropna(axis=0,how='any')
print len(base), len(base1)
base1.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
# 5    5.0                       3.0    2.0   3.0      2.0              3.0
#
#    Musical  Pop  Rock  Metal or Hardrock           ...             Age  \
# 0      1.0  5.0   5.0                1.0           ...            20.0
# 1      2.0  3.0   5.0                4.0           ...            19.0
# 2      5.0  3.0   5.0                3.0           ...            20.0
# 4      3.0  5.0   3.0                1.0           ...            20.0
# 5      3.0  2.0   5.0                5.0           ...            20.0
#
#    Height  Weight  Number of siblings  Gender  Left - right handed  \
# ...

# %%
#Descriptivos basicos
base1.describe()
# Out:
#             Music  Slow songs or fast songs       Dance        Folk  \
# count  674.000000                674.000000  674.000000  674.000000
# mean     4.762611                  3.295252    3.078635    2.264095
# std      0.594699                  0.795833    1.179841    1.120517
# min      1.000000                  1.000000    1.000000    1.000000
# 25%      5.000000                  3.000000    2.000000    1.000000
# 50%      5.000000                  3.000000    3.000000    2.000000
# 75%      5.000000                  4.000000    4.000000    3.000000
# max      5.000000                  5.000000    5.000000    5.000000
#
#           Country  Classical music     Musical         Pop        Rock  \
# count  674.000000       674.000000  674.000000  674.000000  674.000000
# mean     2.117211         2.982196    2.759644    3.451039    3.787834
# std      1.063888         1.244176    1.281403    1.165938    1.152979
# ...

# %% [markdown]
# ## Analisis de las variables musicales. (de la 1 a la 19)

# %%
# Matriz de correlaciones
corr = base1.iloc[:,0:19].corr()
corr
# Out:
#                              Music  Slow songs or fast songs     Dance  \
# Music                     1.000000                  0.079243  0.079587
# Slow songs or fast songs  0.079243                  1.000000  0.122408
# Dance                     0.079587                  0.122408  1.000000
# Folk                      0.065234                 -0.069242  0.091042
# Country                   0.004119                 -0.109378  0.061305
# Classical music           0.092681                 -0.155253 -0.093182
# Musical                   0.065404                 -0.093498  0.121614
# Pop                       0.053930                  0.024410  0.452687
# Rock                      0.162643                  0.011693 -0.150469
# Metal or Hardrock         0.020999                  0.064762 -0.258661
# Punk                      0.084596                  0.056187 -0.161762
# Hiphop, Rap               0.062623                  0.098162  0.400690
# ...

# %%
# Grafico gonito de correlaciones
corr = base1.iloc[:,0:19].corr()

# %pylab inline
plt.figure(figsize=(15, 15))
plt.imshow(corr, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns);
plt.suptitle('Correlations Heat Map', fontsize=15, fontweight='bold')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Tratar de ver la interaccion de las variables graficos(x,y)
# Se busca ver linealidad o relaciones entre una variables
# LAs correlaciones junto estos pueden dar una idea de que variables se pueden "Juntar"
# P.e: Rock, hard rock, punk...
